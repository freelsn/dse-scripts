# %%
# %run get_data.py
benchmarks = ('adpcm_encoder', 'aes', 'ann', 'average', 'decimation', 'fft_fixed', 'fir',
              'idct', 'interpolation', 'kasumi', 'qsort', 'snow3g', 'sobel')
gd = GetData('data/ASIC-2-FPGA', benchmarks)
gd.main()

# %%
# %run methods.py

# %%
# %%time
with open('direct_mapping_v4.csv', 'w') as f4, open('direct_mapping_v5.csv', 'w') as f5:
    f4.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    f5.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    for benchmark in benchmarks:
        print(benchmark)
        print('fpga-v4')
        v4 = DirectMapping.main(gd.data_v4[benchmark], plot_figure=True, display_table=False, with_tolerance=0)
        print_results(v4)
        print('fpga-v5')
        v5 = DirectMapping.main(gd.data_v5[benchmark], plot_figure=True, display_table=False, with_tolerance=0)
        print_results(v5)
        print(50 * '=')
        f4.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v4.values()]) + '\n')
        f5.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v5.values()]) + '\n')
# Out:
# adpcm_encoder
# fpga-v4
# adrs_ave       : 0.02506897283531409
# adrs_max       : 0.09778225806451613
# adrs_ave_rms   : 0.026057874556347293
# adrs_max_rms   : 0.08753267684958413
# hypervolume    : 0.27220855398845356
# dominance      : 0.6666666666666666
# cardinality    : 6
# fpga-v5
# adrs_ave       : 0.012920575454840806
# adrs_max       : 0.05263157894736842
# adrs_ave_rms   : 0.016371992747787726
# adrs_max_rms   : 0.08026905674317902
# hypervolume    : 0.9910657425889381
# dominance      : 0.625
# cardinality    : 6
# ...
# aes
# fpga-v4
# adrs_ave       : 0.004329004329004329
# adrs_max       : 0.021645021645021644
# adrs_ave_rms   : 0.03186418940140229
# adrs_max_rms   : 0.15932094700701144
# hypervolume    : 0.9669070245239897
# dominance      : 0.8
# cardinality    : 6
# fpga-v5
# adrs_ave       : 0.004329004329004329
# adrs_max       : 0.021645021645021644
# adrs_ave_rms   : 0.03673942161145849
# adrs_max_rms   : 0.18369710805729245
# hypervolume    : 0.9690095225716405
# ...

# %%
# %%time
with open('direct_mapping_v4_tolerance_0.1.csv', 'w') as f4, open('direct_mapping_v5_tolerance_0.1.csv', 'w') as f5:
    f4.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    f5.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    for benchmark in benchmarks:
        print(benchmark)
        print('fpga-v4')
        v4 = DirectMapping.main(gd.data_v4[benchmark], plot_figure=True, display_table=False, with_tolerance=0.1)
        print_results(v4)
        print('fpga-v5')
        v5 = DirectMapping.main(gd.data_v5[benchmark], plot_figure=True, display_table=False, with_tolerance=0.1)
        print_results(v5)
        print(50 * '=')
        f4.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v4.values()]) + '\n')
        f5.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v5.values()]) + '\n')
# Out:
# adpcm_encoder
# fpga-v4
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.34470384887942584
# dominance      : 1.0
# cardinality    : 21
# fpga-v5
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.5498833753211496
# dominance      : 1.0
# cardinality    : 21
# ...
# aes
# fpga-v4
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.6741137526154583
# dominance      : 1.0
# cardinality    : 10
# fpga-v5
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.8151468503475355
# dominance      : 1.0
# cardinality    : 10
# ...
# ann
# fpga-v4
# adrs_ave       : 0.0075226432760277795
# adrs_max       : 0.04878048780487805
# adrs_ave_rms   : 0.008237517531075395
# adrs_max_rms   : 0.03690726075749358
# hypervolume    : 0.39831298471248294
# ...

# %%
# %%time
with open('direct_mapping_v4_tolerance_0.05.csv', 'w') as f4, open('direct_mapping_v5_tolerance_0.05.csv', 'w') as f5:
    f4.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    f5.write('benchmark,adrs_ave,adrs_max,adrs_ave_rms,adrs_max_rms,hypervolume,dominance,cardinality\n')
    for benchmark in benchmarks:
        print(benchmark)
        print('fpga-v4')
        v4 = DirectMapping.main(gd.data_v4[benchmark], plot_figure=True, display_table=False, with_tolerance=0.05)
        print_results(v4)
        print('fpga-v5')
        v5 = DirectMapping.main(gd.data_v5[benchmark], plot_figure=True, display_table=False, with_tolerance=0.05)
        print_results(v5)
        print(50 * '=')
        f4.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v4.values()]) + '\n')
        f5.write(benchmark + ',' + ','.join([f'{i:.4f}' for i in v5.values()]) + '\n')
# Out:
# adpcm_encoder
# fpga-v4
# adrs_ave       : 0.011124080362195811
# adrs_max       : 0.05263157894736842
# adrs_ave_rms   : 0.0034204120898145133
# adrs_max_rms   : 0.014112874542996794
# hypervolume    : 0.3133474193529841
# dominance      : 0.6666666666666666
# cardinality    : 15
# fpga-v5
# adrs_ave       : 0.00840186403508772
# adrs_max       : 0.05263157894736842
# adrs_ave_rms   : 0.0022059561249030074
# adrs_max_rms   : 0.008899984587190723
# hypervolume    : 0.5641891144115824
# dominance      : 0.75
# cardinality    : 15
# ...
# aes
# fpga-v4
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.6741137526154583
# dominance      : 1.0
# cardinality    : 10
# fpga-v5
# adrs_ave       : 0.0
# adrs_max       : 0.0
# adrs_ave_rms   : 0.0
# adrs_max_rms   : 0.0
# hypervolume    : 0.8151468503475355
# dominance      : 1.0
# cardinality    : 10
# ...
# ann
# fpga-v4
# adrs_ave       : 0.0075226432760277795
# ...
